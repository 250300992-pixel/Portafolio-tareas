# %%
#Write a short program that takes as input three integers, a, b,andc, from
# the console and determines if they can be used in a correct arithmetic
# formula (in the given order), like “a+b = c,” “a = b−c,” or “a∗b = c.”
# Leer tres números enteros
a = int(input("Ingresa el primer número: "))
b = int(input("Ingresa el segundo número: "))
c = int(input("Ingresa el tercer número: "))

if a+b == c:
    print("a+b=c es correcto")
elif a == b-c:
    print("a == b-c es correcto")
elif a*b == c:
    print("a*b == c es correcto")
else:
    print("No forman una fórmula aritmética válida")
# Out:
# Ingresa el primer número: 3
# Ingresa el segundo número: 4
# Ingresa el tercer número: 5
# No forman una fórmula aritmética válida
